# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# Out:
#   Cell In[7], line 1
#     pip3 install matplotlib
#          ^
# SyntaxError: invalid syntax

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: Data/Bird-drop/
#   inflating: Data/Bird-drop/Bird (42).jpg
#   inflating: Data/Bird-drop/Bird (43).jpg
#   inflating: Data/Bird-drop/Bird (44).jpg
#   inflating: Data/Bird-drop/Bird (45).jpg
#   inflating: Data/Bird-drop/Bird (46).jpg
#   inflating: Data/Bird-drop/Bird (47).jpg
#   inflating: Data/Bird-drop/Bird (48).jpg
#   inflating: Data/Bird-drop/Bird (49).jpg
#   inflating: Data/Bird-drop/Bird (5).jpg
#   inflating: Data/Bird-drop/Bird (50).jpg
#   inflating: Data/Bird-drop/Bird (51).jpg
#   inflating: Data/Bird-drop/Bird (52).jpg
#   inflating: Data/Bird-drop/Bird (53).jpg
#   inflating: Data/Bird-drop/Bird (54).jpg
#   inflating: Data/Bird-drop/Bird (55).jpg
#   inflating: Data/Bird-drop/Bird (56).jpg
#   inflating: Data/Bird-drop/Bird (57).jpg
#   inflating: Data/Bird-drop/Bird (58).jpg
#   inflating: Data/Bird-drop/Bird (59).jpg
#   inflating: Data/Bird-drop/Bird (6).jpg
#   inflating: Data/Bird-drop/Bird (60).jpg
#   inflating: Data/Bird-drop/Bird (61).jpg
#   inflating: Data/Bird-drop/Bird (62).jpg
#   inflating: Data/Bird-drop/Bird (63).jpg
#   inflating: Data/Bird-drop/Bird (64).jpg
#   inflating: Data/Bird-drop/Bird (65).jpg
#   inflating: Data/Bird-drop/Bird (66).jpg
#   inflating: Data/Bird-drop/Bird (67).jpg
#   inflating: Data/Bird-drop/Bird (68).jpg
#   inflating: Data/Bird-drop/Bird (69).JPG
#   inflating: Data/Bird-drop/Bird (7).jpg
#   inflating: Data/Bird-drop/Bird (70).jpg
#   inflating: Data/Bird-drop/Bird (71).jpg
#   inflating: Data/Bird-drop/Bird (72).jpg
#   inflating: Data/Bird-drop/Bird (73).jpg
#   inflating: Data/Bird-drop/Bird (74).jpg
#   inflating: Data/Bird-drop/Bird (75).jpg
#   inflating: Data/Bird-drop/Bird (76).jpg
#   inflating: Data/Bird-drop/Bird (77).jpg
#   inflating: Data/Bird-drop/Bird (78).jpg
#   inflating: Data/Bird-drop/Bird (79).jpg
#   inflating: Data/Bird-drop/Bird (8).jpg
#   inflating: Data/Bird-drop/Bird (80).jpg
#   inflating: Data/Bird-drop/Bird (81).jpg
#   inflating: Data/Bird-drop/Bird (82).jpg
#   inflating: Data/Bird-drop/Bird (83).jpg
#   inflating: Data/Bird-drop/Bird (84).jpg
#   inflating: Data/Bird-drop/Bird (85).jpg
#   inflating: Data/Bird-drop/Bird (86).jpg
#   inflating: Data/Bird-drop/Bird (87).jpg
#   inflating: Data/Bird-drop/Bird (88).jpg
#   inflating: Data/Bird-drop/Bird (89).jpg
#   inflating: Data/Bird-drop/Bird (9).jpg
#   inflating: Data/Bird-drop/Bird (90).jpg
#   inflating: Data/Bird-drop/Bird (91).jpg
#   inflating: Data/Bird-drop/Bird (92).jpg
#   inflating: Data/Bird-drop/Bird (93).jpg
#   inflating: Data/Bird-drop/Bird (94).jpg
#   inflating: Data/Bird-drop/Bird (95).jpg
#   inflating: Data/Bird-drop/Bird (96).jpg
#   inflating: Data/Bird-drop/Bird (97).jpg
#   inflating: Data/Bird-drop/Bird (98).jpg
#   inflating: Data/Bird-drop/Bird (99).jpg
#   inflating: Data/Bird-drop/desktop.ini
#    creating: Data/Bird-drop/New/
#   inflating: Data/Bird-drop/New/1.JPG
#   inflating: Data/Bird-drop/New/10.JPG
#   inflating: Data/Bird-drop/New/11.JPG
#   inflating: Data/Bird-drop/New/12.JPG
#   inflating: Data/Bird-drop/New/13.JPG
#   inflating: Data/Bird-drop/New/14.JPG
#   inflating: Data/Bird-drop/New/15.JPG
#   inflating: Data/Bird-drop/New/16.JPG
#   inflating: Data/Bird-drop/New/2.JPG
#   inflating: Data/Bird-drop/New/3.JPG
#   inflating: Data/Bird-drop/New/4.JPG
#   inflating: Data/Bird-drop/New/5.JPG
#   inflating: Data/Bird-drop/New/6.JPG
#   inflating: Data/Bird-drop/New/7.JPG
#   inflating: Data/Bird-drop/New/8.JPG
#   inflating: Data/Bird-drop/New/9.JPG
#    creating: Data/Clean/
#   inflating: Data/Clean/Clean (1).jpeg
#   inflating: Data/Clean/Clean (10).JPG
#   inflating: Data/Clean/Clean (100).jpg
#   inflating: Data/Clean/Clean (101).jpg
#   inflating: Data/Clean/Clean (102).jpg
#   inflating: Data/Clean/Clean (103).jpg
#   inflating: Data/Clean/Clean (104).jpg
#   inflating: Data/Clean/Clean (105).jpg
#   inflating: Data/Clean/Clean (106).jpg
#   inflating: Data/Clean/Clean (107).jpg
#   inflating: Data/Clean/Clean (108).jpg
#   inflating: Data/Clean/Clean (109).jpg
#   inflating: Data/Clean/Clean (11).jpg
#   inflating: Data/Clean/Clean (110).jpg
#   inflating: Data/Clean/Clean (111).jpg
#   inflating: Data/Clean/Clean (112).jpg
#   inflating: Data/Clean/Clean (113).jpg
#   inflating: Data/Clean/Clean (114).jpg
#   inflating: Data/Clean/Clean (115).jpg
#   inflating: Data/Clean/Clean (116).jpg
#   inflating: Data/Clean/Clean (117).jpg
#   inflating: Data/Clean/Clean (118).jpg
#   inflating: Data/Clean/Clean (119).jpg
#   inflating: Data/Clean/Clean (12).jpg
#   inflating: Data/Clean/Clean (120).jpg
#   inflating: Data/Clean/Clean (121).jpg
#   inflating: Data/Clean/Clean (122).jpg
#   inflating: Data/Clean/Clean (123).jpg
#   inflating: Data/Clean/Clean (124).jpg
#   inflating: Data/Clean/Clean (125).jpg
#   inflating: Data/Clean/Clean (126).jpg
#   inflating: Data/Clean/Clean (127).jpg
#   inflating: Data/Clean/Clean (128).jpg
#   inflating: Data/Clean/Clean (129).jpg
#   inflating: Data/Clean/Clean (13).jpg
#   inflating: Data/Clean/Clean (130).jpg
#   inflating: Data/Clean/Clean (131).jpg
#   inflating: Data/Clean/Clean (132).jpg
#   inflating: Data/Clean/Clean (133).jpg
#   inflating: Data/Clean/Clean (134).jpg
#   inflating: Data/Clean/Clean (135).JPG
#   inflating: Data/Clean/Clean (136).JPG
#   inflating: Data/Clean/Clean (137).jpg
#   inflating: Data/Clean/Clean (138).jpg
#   inflating: Data/Clean/Clean (139).JPG
#   inflating: Data/Clean/Clean (14).jpg
#   inflating: Data/Clean/Clean (140).JPG
#   inflating: Data/Clean/Clean (141).JPG
#   inflating: Data/Clean/Clean (142).jpg
#   inflating: Data/Clean/Clean (143).jpg
#   inflating: Data/Clean/Clean (144).jpg
#   inflating: Data/Clean/Clean (145).jpg
#   inflating: Data/Clean/Clean (146).jpg
#   inflating: Data/Clean/Clean (147).jpg
#   inflating: Data/Clean/Clean (148).jpg
#   inflating: Data/Clean/Clean (149).jpg
#   inflating: Data/Clean/Clean (15).JPG
#   inflating: Data/Clean/Clean (150).jpg
#   inflating: Data/Clean/Clean (151).jpg
#   inflating: Data/Clean/Clean (152).jpg
#   inflating: Data/Clean/Clean (153).jpg
#   inflating: Data/Clean/Clean (154).jpg
#   inflating: Data/Clean/Clean (155).jpg
#   inflating: Data/Clean/Clean (156).jpg
#   inflating: Data/Clean/Clean (157).jpg
#   inflating: Data/Clean/Clean (158).jpg
#   inflating: Data/Clean/Clean (159).jpg
#   inflating: Data/Clean/Clean (16).JPG
#   inflating: Data/Clean/Clean (160).jpg
#   inflating: Data/Clean/Clean (161).jpg
#   inflating: Data/Clean/Clean (162).jpg
#   inflating: Data/Clean/Clean (163).jpg
#   inflating: Data/Clean/Clean (164).jpg
#   inflating: Data/Clean/Clean (165).jpg
#   inflating: Data/Clean/Clean (166).jpg
#   inflating: Data/Clean/Clean (167).jpg
#   inflating: Data/Clean/Clean (168).jpg
#   inflating: Data/Clean/Clean (169).jpg
#   inflating: Data/Clean/Clean (17).jpg
#   inflating: Data/Clean/Clean (170).jpg
#   inflating: Data/Clean/Clean (171).jpg
#   inflating: Data/Clean/Clean (172).jpg
#   inflating: Data/Clean/Clean (173).jpg
#   inflating: Data/Clean/Clean (174).jpg
#   inflating: Data/Clean/Clean (175).jpg
#   inflating: Data/Clean/Clean (176).jpg
#   inflating: Data/Clean/Clean (177).jpg
#   inflating: Data/Clean/Clean (178).jpg
#   inflating: Data/Clean/Clean (179).jpg
#   inflating: Data/Clean/Clean (18).jpg
#   inflating: Data/Clean/Clean (180).jpg
#   inflating: Data/Clean/Clean (181).jpg
#   inflating: Data/Clean/Clean (182).jpg
#   inflating: Data/Clean/Clean (183).jpg
#   inflating: Data/Clean/Clean (184).jpg
#   inflating: Data/Clean/Clean (185).jpg
#   inflating: Data/Clean/Clean (186).jpg
#   inflating: Data/Clean/Clean (187).jpg
#   inflating: Data/Clean/Clean (188).jpg
#   inflating: Data/Clean/Clean (189).jpg
#   inflating: Data/Clean/Clean (19).jpg
#   inflating: Data/Clean/Clean (190).jpg
#   inflating: Data/Clean/Clean (191).jpg
#   inflating: Data/Clean/Clean (192).jpg
#   inflating: Data/Clean/Clean (193).png
#   inflating: Data/Clean/Clean (2).jpg
#   inflating: Data/Clean/Clean (20).jpg
#   inflating: Data/Clean/Clean (21).jpg
#   inflating: Data/Clean/Clean (22).jpg
#   inflating: Data/Clean/Clean (23).jpg
#   inflating: Data/Clean/Clean (24).jpg
#   inflating: Data/Clean/Clean (25).jpg
#   inflating: Data/Clean/Clean (26).jpg
#   inflating: Data/Clean/Clean (27).jpg
#   inflating: Data/Clean/Clean (28).jpg
#   inflating: Data/Clean/Clean (29).jpg
#   inflating: Data/Clean/Clean (3).jpg
#   inflating: Data/Clean/Clean (30).jpg
#   inflating: Data/Clean/Clean (31).jpg
#   inflating: Data/Clean/Clean (32).jpg
#   inflating: Data/Clean/Clean (33).jpg
#   inflating: Data/Clean/Clean (34).jpg
#   inflating: Data/Clean/Clean (35).jpg
#   inflating: Data/Clean/Clean (36).jpg
#   inflating: Data/Clean/Clean (37).jpg
#   inflating: Data/Clean/Clean (38).jpg
#   inflating: Data/Clean/Clean (39).jpg
#   inflating: Data/Clean/Clean (4).jpg
#   inflating: Data/Clean/Clean (40).jpg
#   inflating: Data/Clean/Clean (41).jpg
#   inflating: Data/Clean/Clean (42).jpg
#   inflating: Data/Clean/Clean (43).jpg
#   inflating: Data/Clean/Clean (44).jpg
#   inflating: Data/Clean/Clean (45).jpg
#   inflating: Data/Clean/Clean (46).jpg
#   inflating: Data/Clean/Clean (47).jpg
#   inflating: Data/Clean/Clean (48).jpg
#   inflating: Data/Clean/Clean (49).jpg
#   inflating: Data/Clean/Clean (5).jpg
#   inflating: Data/Clean/Clean (50).jpg
#   inflating: Data/Clean/Clean (51).jpg
#   inflating: Data/Clean/Clean (52).jpg
#   inflating: Data/Clean/Clean (53).jpg
#   inflating: Data/Clean/Clean (54).jpg
#   inflating: Data/Clean/Clean (55).jpg
#   inflating: Data/Clean/Clean (56).jpg
#   inflating: Data/Clean/Clean (57).jpg
#   inflating: Data/Clean/Clean (58).jpg
#   inflating: Data/Clean/Clean (59).jpg
#   inflating: Data/Clean/Clean (6).jpg
#   inflating: Data/Clean/Clean (60).jpg
#   inflating: Data/Clean/Clean (61).jpg
#   inflating: Data/Clean/Clean (62).jpg
#   inflating: Data/Clean/Clean (63).jpg
#   inflating: Data/Clean/Clean (64).jpg
#   inflating: Data/Clean/Clean (65).jpg
#   inflating: Data/Clean/Clean (66).jpg
#   inflating: Data/Clean/Clean (67).jpg
#   inflating: Data/Clean/Clean (68).jpg
#   inflating: Data/Clean/Clean (69).jpg
#   inflating: Data/Clean/Clean (7).jpg
#   inflating: Data/Clean/Clean (70).jpg
#   inflating: Data/Clean/Clean (71).jpg
#   inflating: Data/Clean/Clean (72).jpg
#   inflating: Data/Clean/Clean (73).jpg
#   inflating: Data/Clean/Clean (74).jpg
#   inflating: Data/Clean/Clean (75).jpg
#   inflating: Data/Clean/Clean (76).jpg
#   inflating: Data/Clean/Clean (77).jpg
#   inflating: Data/Clean/Clean (78).jpg
#   inflating: Data/Clean/Clean (79).jpg
#   inflating: Data/Clean/Clean (8).jpg
#   inflating: Data/Clean/Clean (80).jpg
#   inflating: Data/Clean/Clean (81).jpg
#   inflating: Data/Clean/Clean (82).jpg
#   inflating: Data/Clean/Clean (83).jpg
#   inflating: Data/Clean/Clean (84).jpg
#   inflating: Data/Clean/Clean (85).jpg
#   inflating: Data/Clean/Clean (86).jpg
#   inflating: Data/Clean/Clean (87).jpg
#   inflating: Data/Clean/Clean (88).jpg
#   inflating: Data/Clean/Clean (89).jpg
#   inflating: Data/Clean/Clean (9).jpg
#   inflating: Data/Clean/Clean (90).jpg
#   inflating: Data/Clean/Clean (91).jpg
#   inflating: Data/Clean/Clean (92).jpg
#   inflating: Data/Clean/Clean (93).jpg
#   inflating: Data/Clean/Clean (94).jpg
#   inflating: Data/Clean/Clean (95).jpg
#   inflating: Data/Clean/Clean (96).jpg
#   inflating: Data/Clean/Clean (97).jpg
#   inflating: Data/Clean/Clean (98).jpg
#   inflating: Data/Clean/Clean (99).jpg
#   inflating: Data/Clean/desktop.ini
#    creating: Data/Dusty/
#   inflating: Data/Dusty/Dust (1).jpg
#   inflating: Data/Dusty/Dust (10).jpg
#   inflating: Data/Dusty/Dust (100).jpg
#   inflating: Data/Dusty/Dust (101).jpg
#   inflating: Data/Dusty/Dust (102).jpg
#   inflating: Data/Dusty/Dust (103).jpg
#   inflating: Data/Dusty/Dust (104).jpg
#   inflating: Data/Dusty/Dust (105).jpg
#   inflating: Data/Dusty/Dust (106).jpg
#   inflating: Data/Dusty/Dust (107).jpg
#   inflating: Data/Dusty/Dust (108).jpg
#   inflating: Data/Dusty/Dust (109).jpg
#   inflating: Data/Dusty/Dust (11).jpg
#   inflating: Data/Dusty/Dust (110).jpg
#   inflating: Data/Dusty/Dust (111).jpg
#   inflating: Data/Dusty/Dust (112).jpg
#   inflating: Data/Dusty/Dust (113).jpg
#   inflating: Data/Dusty/Dust (114).jpg
#   inflating: Data/Dusty/Dust (115).jpg
#   inflating: Data/Dusty/Dust (116).jpg
#   inflating: Data/Dusty/Dust (117).jpg
#   inflating: Data/Dusty/Dust (118).jpg
#   inflating: Data/Dusty/Dust (119).jpg
#   inflating: Data/Dusty/Dust (12).jpg
#   inflating: Data/Dusty/Dust (120).jpg
#   inflating: Data/Dusty/Dust (121).jpg
#   inflating: Data/Dusty/Dust (122).jpg
#   inflating: Data/Dusty/Dust (123).jpg
#   inflating: Data/Dusty/Dust (124).jpg
#   inflating: Data/Dusty/Dust (125).jpg
#   inflating: Data/Dusty/Dust (126).jpg
#   inflating: Data/Dusty/Dust (127).jpg
#   inflating: Data/Dusty/Dust (128).jpg
#   inflating: Data/Dusty/Dust (129).jpg
#   inflating: Data/Dusty/Dust (13).jpg
#   inflating: Data/Dusty/Dust (130).jpg
#   inflating: Data/Dusty/Dust (131).jpg
#   inflating: Data/Dusty/Dust (132).jpg
#   inflating: Data/Dusty/Dust (133).jpg
#   inflating: Data/Dusty/Dust (134).jpg
#   inflating: Data/Dusty/Dust (135).jpg
#   inflating: Data/Dusty/Dust (136).jpg
#   inflating: Data/Dusty/Dust (137).jpg
#   inflating: Data/Dusty/Dust (138).jpg
#   inflating: Data/Dusty/Dust (139).jpg
#   inflating: Data/Dusty/Dust (14).jpg
#   inflating: Data/Dusty/Dust (140).jpg
#   inflating: Data/Dusty/Dust (141).jpg
#   inflating: Data/Dusty/Dust (142).jpg
#   inflating: Data/Dusty/Dust (143).jpg
#   inflating: Data/Dusty/Dust (144).jpg
#   inflating: Data/Dusty/Dust (145).jpg
#   inflating: Data/Dusty/Dust (146).jpg
#   inflating: Data/Dusty/Dust (147).jpg
#   inflating: Data/Dusty/Dust (148).jpg
#   inflating: Data/Dusty/Dust (149).jpg
#   inflating: Data/Dusty/Dust (15).jpg
#   inflating: Data/Dusty/Dust (150).jpg
#   inflating: Data/Dusty/Dust (151).jpg
#   inflating: Data/Dusty/Dust (152).jpg
#   inflating: Data/Dusty/Dust (153).jpg
#   inflating: Data/Dusty/Dust (154).jpg
#   inflating: Data/Dusty/Dust (155).jpg
#   inflating: Data/Dusty/Dust (156).jpg
#   inflating: Data/Dusty/Dust (157).jpg
#   inflating: Data/Dusty/Dust (158).jpg
#   inflating: Data/Dusty/Dust (159).jpg
#   inflating: Data/Dusty/Dust (16).jpg
#   inflating: Data/Dusty/Dust (160).jpg
#   inflating: Data/Dusty/Dust (161).jpg
#   inflating: Data/Dusty/Dust (162).jpg
#   inflating: Data/Dusty/Dust (163).jpg
#   inflating: Data/Dusty/Dust (164).jpg
#   inflating: Data/Dusty/Dust (165).jpg
#   inflating: Data/Dusty/Dust (166).jpg
#   inflating: Data/Dusty/Dust (167).jpg
#   inflating: Data/Dusty/Dust (168).jpg
#   inflating: Data/Dusty/Dust (169).jpg
#   inflating: Data/Dusty/Dust (17).jpg
#   inflating: Data/Dusty/Dust (170).jpg
#   inflating: Data/Dusty/Dust (171).jpg
#   inflating: Data/Dusty/Dust (172).jpg
#   inflating: Data/Dusty/Dust (173).jpg
#   inflating: Data/Dusty/Dust (174).jpg
#   inflating: Data/Dusty/Dust (175).jpg
#   inflating: Data/Dusty/Dust (176).jpg
#   inflating: Data/Dusty/Dust (177).jpg
#   inflating: Data/Dusty/Dust (178).jpg
#   inflating: Data/Dusty/Dust (179).jpg
#   inflating: Data/Dusty/Dust (18).jpg
#   inflating: Data/Dusty/Dust (180).jpg
#   inflating: Data/Dusty/Dust (181).jpg
#   inflating: Data/Dusty/Dust (182).jpg
#   inflating: Data/Dusty/Dust (183).jpg
#   inflating: Data/Dusty/Dust (184).jpg
#   inflating: Data/Dusty/Dust (185).jpg
#   inflating: Data/Dusty/Dust (186).jpg
#   inflating: Data/Dusty/Dust (187).jpg
#   inflating: Data/Dusty/Dust (188).jpg
#   inflating: Data/Dusty/Dust (189).jpg
#   inflating: Data/Dusty/Dust (19).jpg
#   inflating: Data/Dusty/Dust (190).jpg
#   inflating: Data/Dusty/Dust (2).jpg
#   inflating: Data/Dusty/Dust (20).jpg
#   inflating: Data/Dusty/Dust (21).jpg
#   inflating: Data/Dusty/Dust (22).jpg
#   inflating: Data/Dusty/Dust (23).jpg
#   inflating: Data/Dusty/Dust (24).jpg
#   inflating: Data/Dusty/Dust (25).jpg
#   inflating: Data/Dusty/Dust (26).jpg
#   inflating: Data/Dusty/Dust (27).jpg
#   inflating: Data/Dusty/Dust (28).jpg
#   inflating: Data/Dusty/Dust (29).jpg
#   inflating: Data/Dusty/Dust (3).jpg
#   inflating: Data/Dusty/Dust (30).jpg
#   inflating: Data/Dusty/Dust (31).jpg
#   inflating: Data/Dusty/Dust (32).jpg
#   inflating: Data/Dusty/Dust (33).jpg
#   inflating: Data/Dusty/Dust (34).jpg
#   inflating: Data/Dusty/Dust (35).jpg
#   inflating: Data/Dusty/Dust (36).jpg
#   inflating: Data/Dusty/Dust (37).jpg
#   inflating: Data/Dusty/Dust (38).jpg
#   inflating: Data/Dusty/Dust (39).jpg
#   inflating: Data/Dusty/Dust (4).jpg
#   inflating: Data/Dusty/Dust (40).jpg
#   inflating: Data/Dusty/Dust (41).jpg
#   inflating: Data/Dusty/Dust (42).jpg
#   inflating: Data/Dusty/Dust (43).jpg
#   inflating: Data/Dusty/Dust (44).jpg
#   inflating: Data/Dusty/Dust (45).jpg
#   inflating: Data/Dusty/Dust (46).jpg
#   inflating: Data/Dusty/Dust (47).jpg
#   inflating: Data/Dusty/Dust (48).jpg
#   inflating: Data/Dusty/Dust (49).jpg
#   inflating: Data/Dusty/Dust (5).jpg
#   inflating: Data/Dusty/Dust (50).jpg
#   inflating: Data/Dusty/Dust (51).jpg
#   inflating: Data/Dusty/Dust (52).jpg
#   inflating: Data/Dusty/Dust (53).jpg
#   inflating: Data/Dusty/Dust (54).jpg
#   inflating: Data/Dusty/Dust (55).jpg
#   inflating: Data/Dusty/Dust (56).jpg
#   inflating: Data/Dusty/Dust (57).jpg
#   inflating: Data/Dusty/Dust (58).jpg
#   inflating: Data/Dusty/Dust (59).jpg
#   inflating: Data/Dusty/Dust (6).jpg
#   inflating: Data/Dusty/Dust (60).jpg
#   inflating: Data/Dusty/Dust (61).jpg
#   inflating: Data/Dusty/Dust (62).jpg
#   inflating: Data/Dusty/Dust (63).jpg
#   inflating: Data/Dusty/Dust (64).jpg
#   inflating: Data/Dusty/Dust (65).jpg
#   inflating: Data/Dusty/Dust (66).jpg
#   inflating: Data/Dusty/Dust (67).jpg
#   inflating: Data/Dusty/Dust (68).jpg
#   inflating: Data/Dusty/Dust (69).jpg
#   inflating: Data/Dusty/Dust (7).jpg
#   inflating: Data/Dusty/Dust (70).jpg
#   inflating: Data/Dusty/Dust (71).jpg
#   inflating: Data/Dusty/Dust (72).jpg
#   inflating: Data/Dusty/Dust (73).jpg
#   inflating: Data/Dusty/Dust (74).jpg
#   inflating: Data/Dusty/Dust (75).jpg
#   inflating: Data/Dusty/Dust (76).jpg
#   inflating: Data/Dusty/Dust (77).jpg
#   inflating: Data/Dusty/Dust (78).jpg
#   inflating: Data/Dusty/Dust (79).jpg
#   inflating: Data/Dusty/Dust (8).jpg
#   inflating: Data/Dusty/Dust (80).jpg
#   inflating: Data/Dusty/Dust (81).jpg
#   inflating: Data/Dusty/Dust (82).jpg
#   inflating: Data/Dusty/Dust (83).jpg
#   inflating: Data/Dusty/Dust (84).jpg
#   inflating: Data/Dusty/Dust (85).jpg
#   inflating: Data/Dusty/Dust (86).jpg
#   inflating: Data/Dusty/Dust (87).jpg
#   inflating: Data/Dusty/Dust (88).jpg
#   inflating: Data/Dusty/Dust (89).jpg
#   inflating: Data/Dusty/Dust (9).jpg
#   inflating: Data/Dusty/Dust (90).jpg
#   inflating: Data/Dusty/Dust (91).jpg
#   inflating: Data/Dusty/Dust (92).jpg
#   inflating: Data/Dusty/Dust (93).jpg
#   inflating: Data/Dusty/Dust (94).jpg
#   inflating: Data/Dusty/Dust (95).jpg
#   inflating: Data/Dusty/Dust (96).jpg
#   inflating: Data/Dusty/Dust (97).jpg
#   inflating: Data/Dusty/Dust (98).jpg
#   inflating: Data/Dusty/Dust (99).jpg
#    creating: Data/Electrical-damage/
#   inflating: Data/Electrical-damage/Electrical (1).jpg
#   inflating: Data/Electrical-damage/Electrical (1).png
#   inflating: Data/Electrical-damage/Electrical (10).jpg
#   inflating: Data/Electrical-damage/Electrical (11).jpg
#   inflating: Data/Electrical-damage/Electrical (12).jpg
#   inflating: Data/Electrical-damage/Electrical (13).jpg
#   inflating: Data/Electrical-damage/Electrical (14).jpg
#   inflating: Data/Electrical-damage/Electrical (15).jpg
#   inflating: Data/Electrical-damage/Electrical (16).jpg
#   inflating: Data/Electrical-damage/Electrical (17).jpg
#   inflating: Data/Electrical-damage/Electrical (18).jpg
#   inflating: Data/Electrical-damage/Electrical (19).jpg
#   inflating: Data/Electrical-damage/Electrical (2).JPG
#   inflating: Data/Electrical-damage/Electrical (2).png
#   inflating: Data/Electrical-damage/Electrical (20).jpg
#   inflating: Data/Electrical-damage/Electrical (21).jpg
#   inflating: Data/Electrical-damage/Electrical (22).jpg
#   inflating: Data/Electrical-damage/Electrical (23).jpg
#   inflating: Data/Electrical-damage/Electrical (24).jpg
#   inflating: Data/Electrical-damage/Electrical (25).jpg
#   inflating: Data/Electrical-damage/Electrical (26).jpg
#   inflating: Data/Electrical-damage/Electrical (27).jpg
#   inflating: Data/Electrical-damage/Electrical (28).jpg
#   inflating: Data/Electrical-damage/Electrical (29).jpg
#   inflating: Data/Electrical-damage/Electrical (3).JPG
#   inflating: Data/Electrical-damage/Electrical (3).png
#   inflating: Data/Electrical-damage/Electrical (30).jpg
#   inflating: Data/Electrical-damage/Electrical (31).jpg
#   inflating: Data/Electrical-damage/Electrical (32).jpg
#   inflating: Data/Electrical-damage/Electrical (33).jpg
#   inflating: Data/Electrical-damage/Electrical (34).jpg
#   inflating: Data/Electrical-damage/Electrical (35).jpg
#   inflating: Data/Electrical-damage/Electrical (36).jpg
#   inflating: Data/Electrical-damage/Electrical (37).jpg
#   inflating: Data/Electrical-damage/Electrical (38).jpg
#   inflating: Data/Electrical-damage/Electrical (39).jpg
#   inflating: Data/Electrical-damage/Electrical (4).JPG
#   inflating: Data/Electrical-damage/Electrical (4).png
#   inflating: Data/Electrical-damage/Electrical (40).jpg
#   inflating: Data/Electrical-damage/Electrical (41).jpg
#   inflating: Data/Electrical-damage/Electrical (42).jpg
#   inflating: Data/Electrical-damage/Electrical (43).jpg
#   inflating: Data/Electrical-damage/Electrical (44).jpg
#   inflating: Data/Electrical-damage/Electrical (45).jpg
#   inflating: Data/Electrical-damage/Electrical (46).jpg
#   inflating: Data/Electrical-damage/Electrical (47).jpg
#   inflating: Data/Electrical-damage/Electrical (48).jpg
#   inflating: Data/Electrical-damage/Electrical (49).jpg
#   inflating: Data/Electrical-damage/Electrical (5).jpg
#   inflating: Data/Electrical-damage/Electrical (50).jpg
#   inflating: Data/Electrical-damage/Electrical (51).jpg
#   inflating: Data/Electrical-damage/Electrical (52).jpg
#   inflating: Data/Electrical-damage/Electrical (53).JPG
#   inflating: Data/Electrical-damage/Electrical (54).jpg
#   inflating: Data/Electrical-damage/Electrical (55).jpg
#   inflating: Data/Electrical-damage/Electrical (56).jpg
#   inflating: Data/Electrical-damage/Electrical (57).JPG
#   inflating: Data/Electrical-damage/Electrical (58).jpg
#   inflating: Data/Electrical-damage/Electrical (59).jpg
#   inflating: Data/Electrical-damage/Electrical (6).jpg
#   inflating: Data/Electrical-damage/Electrical (60).jpg
#   inflating: Data/Electrical-damage/Electrical (61).jpg
#   inflating: Data/Electrical-damage/Electrical (62).jpg
#   inflating: Data/Electrical-damage/Electrical (63).jpg
#   inflating: Data/Electrical-damage/Electrical (64).JPG
#   inflating: Data/Electrical-damage/Electrical (65).JPG
#   inflating: Data/Electrical-damage/Electrical (66).JPG
#   inflating: Data/Electrical-damage/Electrical (67).JPG
#   inflating: Data/Electrical-damage/Electrical (68).JPG
#   inflating: Data/Electrical-damage/Electrical (69).jpg
#   inflating: Data/Electrical-damage/Electrical (7).jpg
#   inflating: Data/Electrical-damage/Electrical (70).jpg
#   inflating: Data/Electrical-damage/Electrical (71).jpg
#   inflating: Data/Electrical-damage/Electrical (72).jpg
#   inflating: Data/Electrical-damage/Electrical (73).JPG
#   inflating: Data/Electrical-damage/Electrical (74).jpg
#   inflating: Data/Electrical-damage/Electrical (75).jpg
#   inflating: Data/Electrical-damage/Electrical (76).jpg
#   inflating: Data/Electrical-damage/Electrical (77).jpg
#   inflating: Data/Electrical-damage/Electrical (78).jpg
#   inflating: Data/Electrical-damage/Electrical (79).jpg
#   inflating: Data/Electrical-damage/Electrical (8).jpg
#   inflating: Data/Electrical-damage/Electrical (80).jpg
#   inflating: Data/Electrical-damage/Electrical (81).jpg
#   inflating: Data/Electrical-damage/Electrical (82).jpg
#   inflating: Data/Electrical-damage/Electrical (83).jpg
#   inflating: Data/Electrical-damage/Electrical (84).jpg
#   inflating: Data/Electrical-damage/Electrical (85).JPG
#   inflating: Data/Electrical-damage/Electrical (86).JPG
#   inflating: Data/Electrical-damage/Electrical (87).jpg
#   inflating: Data/Electrical-damage/Electrical (88).jpg
#   inflating: Data/Electrical-damage/Electrical (89).jpg
#   inflating: Data/Electrical-damage/Electrical (9).jpg
#   inflating: Data/Electrical-damage/Electrical (90).jpg
#   inflating: Data/Electrical-damage/Electrical (91).jpg
#   inflating: Data/Electrical-damage/Electrical (92).jpg
#   inflating: Data/Electrical-damage/Electrical (93).jpg
#   inflating: Data/Electrical-damage/Electrical (94).jpg
#   inflating: Data/Electrical-damage/Electrical (95).jpg
#   inflating: Data/Electrical-damage/Electrical (96).jpg
#   inflating: Data/Electrical-damage/Electrical (97).jpg
#   inflating: Data/Electrical-damage/Electrical (98).jpg
#   inflating: Data/Electrical-damage/Electrical (99).jpg
#    creating: Data/Physical-Damage/
#   inflating: Data/Physical-Damage/Physical (1).jpg
#   inflating: Data/Physical-Damage/Physical (10).jpg
#   inflating: Data/Physical-Damage/Physical (11).jpg
#   inflating: Data/Physical-Damage/Physical (12).jpg
#   inflating: Data/Physical-Damage/Physical (13).jpg
#   inflating: Data/Physical-Damage/Physical (14).jpg
#   inflating: Data/Physical-Damage/Physical (15).jpg
#   inflating: Data/Physical-Damage/Physical (16).jpg
#   inflating: Data/Physical-Damage/Physical (17).jpg
#   inflating: Data/Physical-Damage/Physical (18).jpg
#   inflating: Data/Physical-Damage/Physical (19).jpg
#   inflating: Data/Physical-Damage/Physical (2).jpg
#   inflating: Data/Physical-Damage/Physical (20).jpg
#   inflating: Data/Physical-Damage/Physical (21).jpg
#   inflating: Data/Physical-Damage/Physical (22).jpg
#   inflating: Data/Physical-Damage/Physical (23).jpg
#   inflating: Data/Physical-Damage/Physical (24).jpg
#   inflating: Data/Physical-Damage/Physical (25).jpg
#   inflating: Data/Physical-Damage/Physical (26).JPG
#   inflating: Data/Physical-Damage/Physical (27).JPG
#   inflating: Data/Physical-Damage/Physical (28).jpg
#   inflating: Data/Physical-Damage/Physical (29).jpg
#   inflating: Data/Physical-Damage/Physical (3).jpg
#   inflating: Data/Physical-Damage/Physical (30).jpg
#   inflating: Data/Physical-Damage/Physical (31).jpg
#   inflating: Data/Physical-Damage/Physical (32).jpg
#   inflating: Data/Physical-Damage/Physical (33).jpg
#   inflating: Data/Physical-Damage/Physical (34).jpg
#   inflating: Data/Physical-Damage/Physical (35).jpg
#   inflating: Data/Physical-Damage/Physical (36).jpg
#   inflating: Data/Physical-Damage/Physical (37).jpg
#   inflating: Data/Physical-Damage/Physical (38).jpg
#   inflating: Data/Physical-Damage/Physical (39).jpg
#   inflating: Data/Physical-Damage/Physical (4).jpg
#   inflating: Data/Physical-Damage/Physical (40).jpg
#   inflating: Data/Physical-Damage/Physical (41).jpg
#   inflating: Data/Physical-Damage/Physical (42).jpg
#   inflating: Data/Physical-Damage/Physical (43).jpg
#   inflating: Data/Physical-Damage/Physical (44).jpg
#   inflating: Data/Physical-Damage/Physical (45).jpg
#   inflating: Data/Physical-Damage/Physical (46).jpg
#   inflating: Data/Physical-Damage/Physical (47).jpg
#   inflating: Data/Physical-Damage/Physical (48).jpg
#   inflating: Data/Physical-Damage/Physical (49).jpg
#   inflating: Data/Physical-Damage/Physical (5).jpg
#   inflating: Data/Physical-Damage/Physical (50).jpg
#   inflating: Data/Physical-Damage/Physical (51).jpg
#   inflating: Data/Physical-Damage/Physical (52).JPG
#   inflating: Data/Physical-Damage/Physical (53).jpg
#   inflating: Data/Physical-Damage/Physical (54).jpg
#   inflating: Data/Physical-Damage/Physical (55).jpg
#   inflating: Data/Physical-Damage/Physical (56).jpg
#   inflating: Data/Physical-Damage/Physical (57).jpg
#   inflating: Data/Physical-Damage/Physical (58).jpg
#   inflating: Data/Physical-Damage/Physical (59).jpg
#   inflating: Data/Physical-Damage/Physical (6).jpg
#   inflating: Data/Physical-Damage/Physical (60).jpg
#   inflating: Data/Physical-Damage/Physical (61).jpg
#   inflating: Data/Physical-Damage/Physical (62).jpg
#   inflating: Data/Physical-Damage/Physical (63).jpg
#   inflating: Data/Physical-Damage/Physical (64).jpg
#   inflating: Data/Physical-Damage/Physical (65).jpg
#   inflating: Data/Physical-Damage/Physical (66).jpg
#   inflating: Data/Physical-Damage/Physical (67).jpg
#   inflating: Data/Physical-Damage/Physical (68).jpg
#   inflating: Data/Physical-Damage/Physical (69).jpg
#   inflating: Data/Physical-Damage/Physical (7).jpg
#   inflating: Data/Physical-Damage/Physical (8).jpg
#   inflating: Data/Physical-Damage/Physical (9).jpg
#    creating: Data/Snow-Covered/
#   inflating: Data/Snow-Covered/Snow (1).jpg
#   inflating: Data/Snow-Covered/Snow (10).jpg
#   inflating: Data/Snow-Covered/Snow (100).jpg
#   inflating: Data/Snow-Covered/Snow (101).jpg
#   inflating: Data/Snow-Covered/Snow (102).jpg
#   inflating: Data/Snow-Covered/Snow (103).jpg
#   inflating: Data/Snow-Covered/Snow (104).jpg
#   inflating: Data/Snow-Covered/Snow (105).jpg
#   inflating: Data/Snow-Covered/Snow (106).jpg
#   inflating: Data/Snow-Covered/Snow (107).jpg
#   inflating: Data/Snow-Covered/Snow (108).jpg
#   inflating: Data/Snow-Covered/Snow (109).jpg
#   inflating: Data/Snow-Covered/Snow (11).jpg
#   inflating: Data/Snow-Covered/Snow (110).jpg
#   inflating: Data/Snow-Covered/Snow (111).jpg
#   inflating: Data/Snow-Covered/Snow (112).jpg
#   inflating: Data/Snow-Covered/Snow (113).jpg
#   inflating: Data/Snow-Covered/Snow (114).jpg
#   inflating: Data/Snow-Covered/Snow (115).jpg
#   inflating: Data/Snow-Covered/Snow (116).jpg
#   inflating: Data/Snow-Covered/Snow (117).jpg
#   inflating: Data/Snow-Covered/Snow (118).jpg
#   inflating: Data/Snow-Covered/Snow (119).jpg
#   inflating: Data/Snow-Covered/Snow (12).jpg
#   inflating: Data/Snow-Covered/Snow (120).jpg
#   inflating: Data/Snow-Covered/Snow (121).jpg
#   inflating: Data/Snow-Covered/Snow (122).jpg
#   inflating: Data/Snow-Covered/Snow (123).jpg
#   inflating: Data/Snow-Covered/Snow (13).jpg
#   inflating: Data/Snow-Covered/Snow (14).jpg
#   inflating: Data/Snow-Covered/Snow (15).jpg
#   inflating: Data/Snow-Covered/Snow (16).jpg
#   inflating: Data/Snow-Covered/Snow (17).jpg
#   inflating: Data/Snow-Covered/Snow (18).jpg
#   inflating: Data/Snow-Covered/Snow (19).jpg
#   inflating: Data/Snow-Covered/Snow (2).jpg
#   inflating: Data/Snow-Covered/Snow (20).jpg
#   inflating: Data/Snow-Covered/Snow (21).jpg
#   inflating: Data/Snow-Covered/Snow (22).jpg
#   inflating: Data/Snow-Covered/Snow (23).jpg
#   inflating: Data/Snow-Covered/Snow (24).jpg
#   inflating: Data/Snow-Covered/Snow (25).jpg
#   inflating: Data/Snow-Covered/Snow (26).jpg
#   inflating: Data/Snow-Covered/Snow (27).jpg
#   inflating: Data/Snow-Covered/Snow (28).JPG
#   inflating: Data/Snow-Covered/Snow (29).JPG
#   inflating: Data/Snow-Covered/Snow (3).jpg
#   inflating: Data/Snow-Covered/Snow (30).JPG
#   inflating: Data/Snow-Covered/Snow (31).JPG
#   inflating: Data/Snow-Covered/Snow (32).JPG
#   inflating: Data/Snow-Covered/Snow (33).JPG
#   inflating: Data/Snow-Covered/Snow (34).jpg
#   inflating: Data/Snow-Covered/Snow (35).JPG
#   inflating: Data/Snow-Covered/Snow (36).JPG
#   inflating: Data/Snow-Covered/Snow (37).jpg
#   inflating: Data/Snow-Covered/Snow (38).jpg
#   inflating: Data/Snow-Covered/Snow (39).JPG
#   inflating: Data/Snow-Covered/Snow (4).jpg
#   inflating: Data/Snow-Covered/Snow (40).JPG
#   inflating: Data/Snow-Covered/Snow (41).jpg
#   inflating: Data/Snow-Covered/Snow (42).jpg
#   inflating: Data/Snow-Covered/Snow (43).jpg
#   inflating: Data/Snow-Covered/Snow (44).jpg
#   inflating: Data/Snow-Covered/Snow (45).jpg
#   inflating: Data/Snow-Covered/Snow (46).jpg
#   inflating: Data/Snow-Covered/Snow (47).jpg
#   inflating: Data/Snow-Covered/Snow (48).jpg
#   inflating: Data/Snow-Covered/Snow (49).jpg
#   inflating: Data/Snow-Covered/Snow (5).jpg
#   inflating: Data/Snow-Covered/Snow (50).jpg
#   inflating: Data/Snow-Covered/Snow (51).jpg
#   inflating: Data/Snow-Covered/Snow (52).jpg
#   inflating: Data/Snow-Covered/Snow (53).jpg
#   inflating: Data/Snow-Covered/Snow (54).jpg
#   inflating: Data/Snow-Covered/Snow (55).jpg
#   inflating: Data/Snow-Covered/Snow (56).jpg
#   inflating: Data/Snow-Covered/Snow (57).jpg
#   inflating: Data/Snow-Covered/Snow (58).jpg
#   inflating: Data/Snow-Covered/Snow (59).jpg
#   inflating: Data/Snow-Covered/Snow (6).jpg
#   inflating: Data/Snow-Covered/Snow (60).jpg
#   inflating: Data/Snow-Covered/Snow (61).jpg
#   inflating: Data/Snow-Covered/Snow (62).jpg
#   inflating: Data/Snow-Covered/Snow (63).jpg
#   inflating: Data/Snow-Covered/Snow (64).jpg
#   inflating: Data/Snow-Covered/Snow (65).jpg
#   inflating: Data/Snow-Covered/Snow (66).jpg
#   inflating: Data/Snow-Covered/Snow (67).jpg
#   inflating: Data/Snow-Covered/Snow (68).jpg
#   inflating: Data/Snow-Covered/Snow (69).jpg
#   inflating: Data/Snow-Covered/Snow (7).jpg
#   inflating: Data/Snow-Covered/Snow (70).jpg
#   inflating: Data/Snow-Covered/Snow (71).jpg
#   inflating: Data/Snow-Covered/Snow (72).jpg
#   inflating: Data/Snow-Covered/Snow (73).jpg
#   inflating: Data/Snow-Covered/Snow (74).jpg
#   inflating: Data/Snow-Covered/Snow (75).jpg
#   inflating: Data/Snow-Covered/Snow (76).jpg
#   inflating: Data/Snow-Covered/Snow (77).JPG
#   inflating: Data/Snow-Covered/Snow (78).jpg
#   inflating: Data/Snow-Covered/Snow (79).jpg
#   inflating: Data/Snow-Covered/Snow (8).jpg
#   inflating: Data/Snow-Covered/Snow (80).jpg
#   inflating: Data/Snow-Covered/Snow (81).JPG
#   inflating: Data/Snow-Covered/Snow (82).JPG
#   inflating: Data/Snow-Covered/Snow (83).jpg
#   inflating: Data/Snow-Covered/Snow (84).jpg
#   inflating: Data/Snow-Covered/Snow (85).jpg
#   inflating: Data/Snow-Covered/Snow (86).jpg
#   inflating: Data/Snow-Covered/Snow (87).JPG
#   inflating: Data/Snow-Covered/Snow (88).JPG
#   inflating: Data/Snow-Covered/Snow (89).jpg
#   inflating: Data/Snow-Covered/Snow (9).jpg
#   inflating: Data/Snow-Covered/Snow (90).jpg
#   inflating: Data/Snow-Covered/Snow (91).JPG
#   inflating: Data/Snow-Covered/Snow (92).JPG
#   inflating: Data/Snow-Covered/Snow (93).JPG
#   inflating: Data/Snow-Covered/Snow (94).jpg
#   inflating: Data/Snow-Covered/Snow (95).jpg
#   inflating: Data/Snow-Covered/Snow (96).jpg
#   inflating: Data/Snow-Covered/Snow (97).jpg
#   inflating: Data/Snow-Covered/Snow (98).jpg
#   inflating: Data/Snow-Covered/Snow (99).jpg

# %%
DATASET_DIR = r"C:\Users\salon\OneDrive\Desktop\Data_Science\Deep Learning\Solar-panel-defect-detection\data"
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32
SEED = 42

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split = 0.2,
    subset="training",
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    seed = SEED
)
# Out:
# Found 757 files belonging to 6 classes.
# Using 606 files for training.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split = 0.2,
    subset="validation",
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    seed = SEED
)
# Out:
# Found 757 files belonging to 6 classes.
# Using 151 files for validation.

# %%
class_names = train_dataset.class_names
num_classes = len(class_names)

# %%
class_names
# Out:
# ['Bird-drop',
#  'Clean',
#  'Dusty',
#  'Electrical-damage',
#  'Physical-Damage',
#  'Snow-Covered']

# %%
num_classes
# Out:
# 6

# %% [markdown]
# ## Base Model (CNN2D)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(1.0/255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))

# Convolution layer: 1
model.add(tf.keras.layers.Conv2D(32, (3,3), activation="relu"))
model.add(tf.keras.layers.MaxPooling2D((2,2)))

# Convolution layer: 2
model.add(tf.keras.layers.Conv2D(64, (3,3), activation="relu"))
model.add(tf.keras.layers.MaxPooling2D((2,2)))

# Convolution layer: 3
model.add(tf.keras.layers.Conv2D(128, (3,3), activation="relu"))
model.add(tf.keras.layers.MaxPooling2D((2,2)))

# Flattening
model.add(tf.keras.layers.Flatten())

# FCL
model.add(tf.keras.layers.Dense(128, activation="relu"))

# Output layer
model.add(tf.keras.layers.Dense(num_classes, activation="softmax"))

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 11169734 (42.61 MB)
# Trainable params: 11169734 (42.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
EPOCHS = 10

# %%
history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS
)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 41s 2s/step - loss: 2.0586 - accuracy: 0.2607 - val_loss: 1.6805 - val_accuracy: 0.3311
# Epoch 2/10
# 19/19 [==============================] - 32s 2s/step - loss: 1.5532 - accuracy: 0.4043 - val_loss: 1.5240 - val_accuracy: 0.3907
# Epoch 3/10
# 19/19 [==============================] - 34s 2s/step - loss: 1.3877 - accuracy: 0.5347 - val_loss: 1.3348 - val_accuracy: 0.5099
# Epoch 4/10
# 19/19 [==============================] - 32s 2s/step - loss: 1.0707 - accuracy: 0.6221 - val_loss: 1.3752 - val_accuracy: 0.5166
# Epoch 5/10
# 19/19 [==============================] - 33s 2s/step - loss: 0.8910 - accuracy: 0.6914 - val_loss: 1.4638 - val_accuracy: 0.4636
# Epoch 6/10
# 19/19 [==============================] - 34s 2s/step - loss: 0.7361 - accuracy: 0.7409 - val_loss: 1.4906 - val_accuracy: 0.5894
# Epoch 7/10
# 19/19 [==============================] - 48s 2s/step - loss: 0.5283 - accuracy: 0.8366 - val_loss: 1.5090 - val_accuracy: 0.6291
# Epoch 8/10
# 19/19 [==============================] - 107s 5s/step - loss: 0.3085 - accuracy: 0.8993 - val_loss: 1.9752 - val_accuracy: 0.6490
# Epoch 9/10
# 19/19 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9257

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, EPOCHS + 1)

plt.figure(figsize= (10,5))
plt.plot(epochs, train_accuracy, label = 'Training Accuracy', marker = 'o')
plt.plot(epochs, val_accuracy, label = 'Validation Accuracy', marker = 'o')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
EPOCHS = 20

history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS
)
# Out:
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step - accuracy: 0.9884 - loss: 0.0397 - val_accuracy: 0.5706 - val_loss: 2.0574
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9897 - loss: 0.0546 - val_accuracy: 0.5819 - val_loss: 2.0676
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 144s 4s/step - accuracy: 0.9940 - loss: 0.0287 - val_accuracy: 0.6045 - val_loss: 1.9664
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.9888 - loss: 0.0529 - val_accuracy: 0.6158 - val_loss: 1.7767
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - accuracy: 0.9950 - loss: 0.0225 - val_accuracy: 0.6271 - val_loss: 2.0304
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 146s 4s/step - accuracy: 0.9980 - loss: 0.0136 - val_accuracy: 0.6215 - val_loss: 2.1586
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.9934 - loss: 0.0218 - val_accuracy: 0.6215 - val_loss: 1.7693
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.9916 - loss: 0.0208 - val_accuracy: 0.6328 - val_loss: 1.8229
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 138s 4s/step - accuracy: 0.9955 - loss: 0.0112 - val_accuracy: 0.5706 - val_loss: 2.4765
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.9977 - loss: 0.0258 - val_accuracy: 0.6328 - val_loss: 1.7744
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - accuracy: 0.9961 - loss: 0.0231 - val_accuracy: 0.6441 - val_loss: 1.7801
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.9990 - loss: 0.0098 - val_accuracy: 0.6441 - val_loss: 1.8582
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.9872 - loss: 0.0313 - val_accuracy: 0.6328 - val_loss: 1.7554
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.6271 - val_loss: 1.8868
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 140s 4s/step - accuracy: 0.9967 - loss: 0.0167 - val_accuracy: 0.6271 - val_loss: 1.8773
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.9951 - loss: 0.0138 - val_accuracy: 0.6610 - val_loss: 1.9629
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.9977 - loss: 0.0114 - val_accuracy: 0.6215 - val_loss: 1.7928
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.9942 - loss: 0.0156 - val_accuracy: 0.6102 - val_loss: 1.8189
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - accuracy: 0.9938 - loss: 0.0207 - val_accuracy: 0.6158 - val_loss: 1.8189
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.9980 - loss: 0.0095 - val_accuracy: 0.6102 - val_loss: 1.9628

# %% [markdown]
# ## Solve the Overfitting problem

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch,lr):
  if epoch > 5:
    return lr*0.1
  return lr

lr_schedule = LearningRateScheduler(scheduler)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(1.0/255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))

# Convolution layer: 1
model.add(tf.keras.layers.Conv2D(32, (3,3), activation="relu"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2,2)))
model.add(tf.keras.layers.Dropout(0.3))

# Convolution layer: 2
model.add(tf.keras.layers.Conv2D(64, (3,3), activation="relu"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2,2)))
model.add(tf.keras.layers.Dropout(0.3))

# Convolution layer: 3
model.add(tf.keras.layers.Conv2D(128, (3,3), activation="relu"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2,2)))
model.add(tf.keras.layers.Dropout(0.3))

# Flattening
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))

# FCL
model.add(tf.keras.layers.Dense(128, activation="relu"))

# Output layer
model.add(tf.keras.layers.Dense(num_classes, activation="softmax"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
EPOCHS = 10

# %%
history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = EPOCHS
)
# Out:
# Epoch 1/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 139s 6s/step - accuracy: 0.2845 - loss: 25.7296 - val_accuracy: 0.1186 - val_loss: 5.8220
# Epoch 2/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.4809 - loss: 2.5145 - val_accuracy: 0.1695 - val_loss: 16.7249
# Epoch 3/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.6171 - loss: 1.2151 - val_accuracy: 0.1525 - val_loss: 20.1069
# Epoch 4/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.6597 - loss: 1.0460 - val_accuracy: 0.0452 - val_loss: 24.2745
# Epoch 5/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 136s 4s/step - accuracy: 0.7300 - loss: 0.7382 - val_accuracy: 0.1808 - val_loss: 15.4532
# Epoch 6/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 112s 5s/step - accuracy: 0.7431 - loss: 0.7751 - val_accuracy: 0.2429 - val_loss: 12.3501
# Epoch 7/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 105s 5s/step - accuracy: 0.7682 - loss: 0.6120 - val_accuracy: 0.2768 - val_loss: 8.3462
# Epoch 8/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 106s 5s/step - accuracy: 0.7701 - loss: 0.6512 - val_accuracy: 0.2486 - val_loss: 7.4960
# Epoch 9/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8184 - loss: 0.5893 - val_accuracy: 0.2768 - val_loss: 7.2310
# Epoch 10/10
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - accuracy: 0.8580 - loss: 0.4053 - val_accuracy: 0.2881 - val_loss: 8.0905

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    RandomFlip, RandomRotation, RandomZoom,
    Rescaling, Conv2D, BatchNormalization, MaxPooling2D,
    Flatten, Dropout, Dense, GlobalAveragePooling2D
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %%
data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.15),
    RandomZoom(0.15),
    # Optional: add RandomContrast(0.2) if colors vary a lot
])

# %% [markdown]
# ## Grok.com's recommendation

# %%
# -------------------------------
# Build the Model
# -------------------------------
model = tf.keras.models.Sequential()

# Input + Augmentation + Rescaling
model.add(data_augmentation)
model.add(Rescaling(1.0/255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))

# Conv Block 1
model.add(Conv2D(32, (3,3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), activation="relu", padding="same"))  # Extra layer for better features
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

# Conv Block 2
model.add(Conv2D(64, (3,3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

# Conv Block 3
model.add(Conv2D(128, (3,3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), activation="relu", padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.35))

# Classifier
model.add(Flatten())
# Alternative (often better): use GlobalAveragePooling2D() instead of Flatten()
# model.add(GlobalAveragePooling2D())

model.add(Dense(256, activation="relu", kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation="relu", kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_classes, activation="softmax"))

# -------------------------------
# Compile with lower initial LR
# -------------------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),  # Reduced from default 1e-3
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# -------------------------------
# Callbacks
# -------------------------------
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=7,           # More patient now that we have augmentation
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,           # Halve LR when plateau
    patience=3,
    min_lr=1e-7,
    verbose=1
)

callbacks = [early_stopping, reduce_lr]

# -------------------------------
# Train the model
# -------------------------------
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=50,  # Allow more epochs since early stopping will protect us
    callbacks=callbacks,
    verbose=1
)

# Optional: Print final results
print("\nTraining complete!")
print(f"Best validation accuracy: {max(history.history['val_accuracy']):.4f}")
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 290s 12s/step - accuracy: 0.2432 - loss: 3.2436 - val_accuracy: 0.0904 - val_loss: 3.5180 - learning_rate: 3.0000e-04
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 316s 12s/step - accuracy: 0.3715 - loss: 2.7390 - val_accuracy: 0.0904 - val_loss: 5.5095 - learning_rate: 3.0000e-04
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 319s 12s/step - accuracy: 0.4776 - loss: 2.4514 - val_accuracy: 0.0904 - val_loss: 9.1453 - learning_rate: 3.0000e-04
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.5126 - loss: 2.2639
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 276s 12s/step - accuracy: 0.5123 - loss: 2.2667 - val_accuracy: 0.0904 - val_loss: 9.7419 - learning_rate: 3.0000e-04
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 264s 11s/step - accuracy: 0.4971 - loss: 2.4359 - val_accuracy: 0.0904 - val_loss: 10.3015 - learning_rate: 1.5000e-04
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 253s 11s/step - accuracy: 0.5292 - loss: 2.2836 - val_accuracy: 0.0904 - val_loss: 11.9696 - learning_rate: 1.5000e-04
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.5315 - loss: 2.3518
# Epoch 7: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 271s 11s/step - accuracy: 0.5313 - loss: 2.3484 - val_accuracy: 0.0904 - val_loss: 15.3429 - learning_rate: 1.5000e-04
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 259s 11s/step - accuracy: 0.5535 - loss: 2.1053 - val_accuracy: 0.0904 - val_loss: 22.3769 - learning_rate: 7.5000e-05
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Training complete!
# Best validation accuracy: 0.0904

# %% [markdown]
# ## Transfer Learning - MobileNetV2

# %%
#MobileNetV2 base model

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet'
)

# %%
base_model.trainable = False

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Input(shape=(224,224,3)))
model.add(data_augmentation)
model.add(tf.keras.layers.Rescaling(1.0/255))

model.add(base_model)
model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,726 (9.24 MB)
#  Trainable params: 164,742 (643.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=20
)
# Out:
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.3015 - loss: 2.0307 - val_accuracy: 0.5932 - val_loss: 1.1339
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.5933 - loss: 1.0827 - val_accuracy: 0.5537 - val_loss: 1.0611
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.7044 - loss: 0.8076 - val_accuracy: 0.6271 - val_loss: 0.8905
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.7594 - loss: 0.7203 - val_accuracy: 0.6554 - val_loss: 0.9244
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.7791 - loss: 0.6582 - val_accuracy: 0.6554 - val_loss: 0.9675
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8036 - loss: 0.6116 - val_accuracy: 0.7119 - val_loss: 0.8031
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.8083 - loss: 0.5273 - val_accuracy: 0.5989 - val_loss: 1.0753
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.8172 - loss: 0.4603 - val_accuracy: 0.6158 - val_loss: 0.9935
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8458 - loss: 0.4454 - val_accuracy: 0.7627 - val_loss: 0.7267
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8426 - loss: 0.4304 - val_accuracy: 0.6102 - val_loss: 1.0425
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8434 - loss: 0.4789 - val_accuracy: 0.7458 - val_loss: 0.7103
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8691 - loss: 0.4112 - val_accuracy: 0.6667 - val_loss: 0.8784
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8439 - loss: 0.4246 - val_accuracy: 0.7062 - val_loss: 0.8914
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8595 - loss: 0.4115 - val_accuracy: 0.6949 - val_loss: 0.8008
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8942 - loss: 0.3139 - val_accuracy: 0.6045 - val_loss: 1.1324
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.8781 - loss: 0.3745 - val_accuracy: 0.6328 - val_loss: 0.9489
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.8802 - loss: 0.3256 - val_accuracy: 0.7458 - val_loss: 0.6893
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.8647 - loss: 0.3477 - val_accuracy: 0.6554 - val_loss: 0.9370
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9124 - loss: 0.2934 - val_accuracy: 0.7401 - val_loss: 0.7743
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8732 - loss: 0.3651 - val_accuracy: 0.6554 - val_loss: 0.9227

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, 21)

plt.figure(figsize= (10,5))
plt.plot(epochs, train_accuracy, label = 'Training Accuracy', marker = 'o')
plt.plot(epochs, val_accuracy, label = 'Validation Accuracy', marker = 'o')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save('/content/drive/MyDrive/Krish AI/Solar Panel Classification/mobilenetv2_2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## EfficientNet

# %%
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split = 0.2,
    subset="training",
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    seed = SEED
)
# Out:
# Found 885 files belonging to 6 classes.
# Using 708 files for training.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_DIR,
    validation_split = 0.2,
    subset="validation",
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    seed = SEED
)
# Out:
# Found 885 files belonging to 6 classes.
# Using 177 files for validation.

# %%
class_names = train_dataset.class_names

# %%
class_names
# Out:
# ['Bird-drop',
#  'Clean',
#  'Dusty',
#  'Electrical-damage',
#  'Physical-Damage',
#  'Snow-Covered']

# %%
num_classes = len(class_names)

# %%
num_classes
# Out:
# 6

# %%
class_counts = {}
total_images = 0

for class_name in class_names:
  class_path = os.path.join(DATASET_DIR, class_name)
  count = len(os.listdir(class_path))
  class_counts[class_name] = count
  total_images += count

# %%
class_weights = {}

for index, class_name in enumerate(class_names):
  class_weights[index] = total_images / (num_classes * class_counts[class_name])

print("Class weights", class_weights)
# Out:
# Class weights {0: 0.7530224525043178, 1: 0.7491408934707904, 2: 0.7649122807017544, 3: 1.4110032362459546, 4: 2.106280193236715, 5: 1.1815718157181572}

# %%
data_augmentation = tf.keras.Sequential()
data_augmentation.add(tf.keras.layers.RandomFlip("horizontal"))
data_augmentation.add(tf.keras.layers.RandomRotation(0.1))
data_augmentation.add(tf.keras.layers.RandomZoom(0.1))

# %%
train_images = []
train_labels = []

# %%
for images, labels in train_dataset:
  images = preprocess_input(images)
  train_images.append(images)
  train_labels.append(labels)

# %%
train_images = tf.concat(train_images, axis=0)
train_labels = tf.concat(train_labels, axis=0)

# %%
validation_images = []
validation_labels = []

# %%
for images, labels in validation_dataset:
  images = preprocess_input(images)
  validation_images.append(images)
  validation_labels.append(labels)

# %%
validation_images = tf.concat(validation_images, axis=0)
validation_labels = tf.concat(validation_labels, axis=0)

# %%
base_model = tf.keras.applications.EfficientNetB0(
    input_shape = (224,224,3),
    include_top = False,
    weights="imagenet"
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.trainable = False

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Input(shape=(224,224,3)))
model.add(data_augmentation)

model.add(base_model)
model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,214,313 (16.08 MB)
#  Trainable params: 164,742 (643.52 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
history = model.fit(
    train_dataset,
    validation_data = validation_dataset,
    epochs = 15
)
# Out:
# Epoch 1/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 108s 4s/step - accuracy: 0.4535 - loss: 1.4108 - val_accuracy: 0.6384 - val_loss: 0.9960
# Epoch 2/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7626 - loss: 0.7185 - val_accuracy: 0.7232 - val_loss: 0.7701
# Epoch 3/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.7908 - loss: 0.5914 - val_accuracy: 0.7006 - val_loss: 0.7677
# Epoch 4/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8145 - loss: 0.5026 - val_accuracy: 0.7684 - val_loss: 0.6827
# Epoch 5/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8505 - loss: 0.4751 - val_accuracy: 0.7740 - val_loss: 0.6613
# Epoch 6/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.8780 - loss: 0.3656 - val_accuracy: 0.8136 - val_loss: 0.6479
# Epoch 7/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.8834 - loss: 0.3357 - val_accuracy: 0.7571 - val_loss: 0.6360
# Epoch 8/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.9097 - loss: 0.2941 - val_accuracy: 0.7966 - val_loss: 0.6323
# Epoch 9/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.9197 - loss: 0.2485 - val_accuracy: 0.7740 - val_loss: 0.6111
# Epoch 10/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9335 - loss: 0.2600 - val_accuracy: 0.7797 - val_loss: 0.6155
# Epoch 11/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9189 - loss: 0.2791 - val_accuracy: 0.8023 - val_loss: 0.5747
# Epoch 12/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.9321 - loss: 0.2291 - val_accuracy: 0.7853 - val_loss: 0.6520
# Epoch 13/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.9363 - loss: 0.2172 - val_accuracy: 0.7966 - val_loss: 0.6389
# Epoch 14/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - accuracy: 0.9578 - loss: 0.1812 - val_accuracy: 0.8136 - val_loss: 0.6167
# Epoch 15/15
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.9641 - loss: 0.1684 - val_accuracy: 0.7966 - val_loss: 0.6389

# %% [markdown]
# ## Hyper Parameter Optimization

# %%
# !pip install keras-tuner  # Run if not installed

import keras_tuner as kt
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Reuse your train_dataset and validation_dataset (with preprocess_input already applied)
# Make sure they are defined as in your original code

def build_model(hp):
    base_model = EfficientNetB0(
        input_shape=(224, 224, 3),
        include_top=False,
        weights="imagenet"
    )
    base_model.trainable = False

    model = Sequential([
        RandomFlip("horizontal"),
        RandomRotation(hp.Float("rotation_factor", min_value=0.05, max_value=0.3, step=0.05)),
        RandomZoom(hp.Float("zoom_factor", min_value=0.05, max_value=0.3, step=0.05)),
        base_model,
        GlobalAveragePooling2D(),
        Dropout(hp.Float("dropout_rate", min_value=0.0, max_value=0.5, step=0.1)),
        Dense(
            hp.Int("dense_units", min_value=64, max_value=512, step=64),
            activation='relu'
        ),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log")),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Setup Random Search Tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,          # Same as n_iter before
    executions_per_trial=1,
    directory='kt_dir',
    project_name='efficientnet_tune',
    overwrite=True
)

# Optional: Early stopping
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Run the search
tuner.search(
    train_dataset,
    validation_data=validation_dataset,
    epochs=20,
    callbacks=[early_stopping],
    class_weight=class_weights  # Handles imbalance
)

# Results
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best hyperparameters:")
print(best_hps.values)

best_model = tuner.get_best_models(num_models=1)[0]

# Evaluate on validation
val_loss, val_acc = best_model.evaluate(validation_dataset)
print(f"Best validation accuracy: {val_acc:.4f}")
# Out:
# Trial 20 Complete [00h 15m 23s]
# val_accuracy: 0.7796609997749329
#
# Best val_accuracy So Far: 0.8305084705352783
# Total elapsed time: 06h 49m 09s
# Best hyperparameters:
# {'rotation_factor': 0.05, 'zoom_factor': 0.05, 'dropout_rate': 0.4, 'dense_units': 128, 'learning_rate': 0.002910285815853156}
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8578 - loss: 0.4483
# Best validation accuracy: 0.8305

# %%
best_model.save("solar_model.keras")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
